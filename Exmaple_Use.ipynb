# %% [markdown]
# # Image Prediction

# %%
from CNN_LSTM import *
# Out:
# /home/rs4623/miniconda3/envs/GEMS1/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/rs4623/miniconda3/envs/GEMS1/lib/python3.9/site-packages/torchvision/image.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSs'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# Here we use the pretrained model, which needs to be downloaded to the repo.
# The link for it is:
#
# https://drive.google.com/file/d/1---jSknfU_n_069Fk3Lw-T4m7MMLciYG/view?usp=sharing
#
# We should download the `.pth file` from this link to a proper path which is called when `load_model` below.

# %%
model = load_model('./CNN_LSTM_tst.pth', num_future_steps=3)

# %% [markdown]
# New storm needs to be saved in folder 'surprise_storm'

# %%
file_loc = './surprise_storm/tst/'
output = preprocess_input(file_loc, length=250)

# %%
output.size()
# Out:
# torch.Size([1, 250, 1, 128, 128])

# %%
predicted_images = perform_inference(model,output)

# %%
plot_images(predicted_images)
# Out:
# torch.Size([1, 3, 1, 128, 128])
